# %% [markdown]
# # xiao

# %% [markdown]
# # xiaoxiaoran

# %%
len??

# %% [markdown]
# ## ss

# %%
print??

# %%
print('hello jupyter')
# Out:
# hello jupyter

# %%
# %time foo(100,10000)
# Out:
# Wall time: 997 µs
# ...

# %%
# %timeit foo(100,10000)
# Out:
# 1.33 ms ± 108 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# !dir
# Out:
#  ������ C �еľ��� Win10
#  �������к��� 14BE-D130
#
#  C:\Users\Administrator\AppData\Roaming\Python\Python36\Scripts ��Ŀ¼
#
# 2021/03/06  16:40    <DIR>          .
# 2021/03/06  16:40    <DIR>          ..
# 2021/03/06  14:56    <DIR>          .ipynb_checkpoints
# 2021/01/29  20:24               455 autopep8-script.py
# 2021/01/29  20:24            74,752 autopep8.exe
# 2021/02/19  11:18           106,393 iptest.exe
# 2021/02/19  11:18           106,393 iptest3.exe
# 2021/02/19  11:18           106,386 ipython.exe
# 2021/02/19  11:18           106,386 ipython3.exe
# 2021/02/19  11:18           106,385 jupyter-kernel.exe
# 2021/02/19  11:18           106,423 jupyter-kernelspec.exe
# 2021/02/19  11:18           106,381 jupyter-migrate.exe
# 2021/02/19  11:18           106,402 jupyter-run.exe
# 2021/02/19  11:18           106,386 jupyter-troubleshoot.exe
# 2021/02/19  11:18           106,381 jupyter.exe
# 2021/01/29  20:24            98,185 pycodestyle.exe
# ...

# %%
lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
import numpy as np
np.linspace()

# %%
    # %run xiao-1.py
# Out:
# 1
# 1
# 4
# 27
# 256
# 3125
# 46656
# 823543
# 16777216
# 387420489

# %%
a=1

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# %who
# Out:
# a	 foo	 i	 np

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# a          int         1
# foo        function    <function foo at 0x000001FF60A33BF8>
# i          int         9
# np         module      <module 'numpy' from 'c:\<...>ges\\numpy\\__init__.py'>

# %%
# %who_ls
# Out:
# ['a', 'foo', 'i', 'np']

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(20)
y = x**10
plt.plot(x,y)
